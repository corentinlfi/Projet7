# %%
import requests
import pandas as pd
pd.set_option('display.max_rows', None)

# Demander l'ID du client
client_id = input("Entrez l'ID du client recherché :")  # Remplacez par un ID valide

# Faire la requête à l'API
response = requests.get(f"http://ec2-35-181-57-191.eu-west-3.compute.amazonaws.com:8000/predict/{client_id}")

# Vérifier la réponse
if response.status_code == 200:
    result = response.json()
    #print(result)
    
    # Afficher l'ID du client et si le client est solvable
    print(f"Client ID: {result['client_id']}, Solvable: {result['solvable']}, Score: {result['probability']}")
    
    # Convertir les features en DataFrame
    client_features = result['client_features']
    client_features_df = pd.DataFrame(client_features)
    
    # Afficher le DataFrame des features
    print("Informations sur le client :")
    display(client_features_df)
    
else:
    # En cas d'erreur, afficher le message d'erreur
    print("Error:", response.status_code, response.text)
# Out:
# Entrez l'ID du client recherché : 307508
# Client ID: 307508, Solvable: True, Score: 0.6663322557140986
# Informations sur le client :
#                                                feature     value
# 0                                           SK_ID_CURR    307508
# 1                                   NAME_CONTRACT_TYPE         0
# 2                                         FLAG_OWN_CAR         1
# 3                                      FLAG_OWN_REALTY         0
# 4                                         CNT_CHILDREN         0
# 5                                     AMT_INCOME_TOTAL  281250.0
# 6                                           AMT_CREDIT  855882.0
# 7                                          AMT_ANNUITY   33943.5
# 8                                      AMT_GOODS_PRICE  765000.0
# 9                           REGION_POPULATION_RELATIVE   0.04622
# 10                                          DAYS_BIRTH     10602
# 11                                       DAYS_EMPLOYED   -1931.0
# 12                                   DAYS_REGISTRATION   -1785.0
# 13                                     DAYS_ID_PUBLISH     -3186
# 14                                         OWN_CAR_AGE       8.0
# 15                                          FLAG_MOBIL         1
# 16                                      FLAG_EMP_PHONE         1
# 17                                     FLAG_WORK_PHONE         1
# 18                                    FLAG_CONT_MOBILE         1
# 19                                          FLAG_PHONE         0
# 20                                          FLAG_EMAIL         0
# 21                                     CNT_FAM_MEMBERS       1.0
# 22                                REGION_RATING_CLIENT         1
# 23                         REGION_RATING_CLIENT_W_CITY         1
# 24                             HOUR_APPR_PROCESS_START        16
# 25                          REG_REGION_NOT_LIVE_REGION         0
# 26                          REG_REGION_NOT_WORK_REGION         1
# 27                         LIVE_REGION_NOT_WORK_REGION         1
# 28                              REG_CITY_NOT_LIVE_CITY         0
# 29                              REG_CITY_NOT_WORK_CITY         1
# 30                             LIVE_CITY_NOT_WORK_CITY         1
# 31                                        EXT_SOURCE_1  0.382538
# 32                                        EXT_SOURCE_2  0.373798
# 33                                        EXT_SOURCE_3  0.497469
# 34                                      APARTMENTS_AVG       0.0
# 35                                    BASEMENTAREA_AVG       0.0
# 36                         YEARS_BEGINEXPLUATATION_AVG       0.0
# 37                                     YEARS_BUILD_AVG       0.0
# 38                                      COMMONAREA_AVG       0.0
# 39                                       ELEVATORS_AVG       0.0
# 40                                       ENTRANCES_AVG       0.0
# 41                                       FLOORSMAX_AVG       0.0
# 42                                       FLOORSMIN_AVG       0.0
# 43                                        LANDAREA_AVG       0.0
# 44                                LIVINGAPARTMENTS_AVG       0.0
# 45                                      LIVINGAREA_AVG       0.0
# 46                             NONLIVINGAPARTMENTS_AVG       0.0
# 47                                   NONLIVINGAREA_AVG       0.0
# 48                                     APARTMENTS_MODE       0.0
# 49                                   BASEMENTAREA_MODE       0.0
# 50                        YEARS_BEGINEXPLUATATION_MODE       0.0
# 51                                    YEARS_BUILD_MODE       0.0
# 52                                     COMMONAREA_MODE       0.0
# 53                                      ELEVATORS_MODE       0.0
# 54                                      ENTRANCES_MODE       0.0
# 55                                      FLOORSMAX_MODE       0.0
# 56                                      FLOORSMIN_MODE       0.0
# 57                                       LANDAREA_MODE       0.0
# 58                               LIVINGAPARTMENTS_MODE       0.0
# 59                                     LIVINGAREA_MODE       0.0
# 60                            NONLIVINGAPARTMENTS_MODE       0.0
# 61                                  NONLIVINGAREA_MODE       0.0
# 62                                     APARTMENTS_MEDI       0.0
# 63                                   BASEMENTAREA_MEDI       0.0
# 64                        YEARS_BEGINEXPLUATATION_MEDI       0.0
# 65                                    YEARS_BUILD_MEDI       0.0
# 66                                     COMMONAREA_MEDI       0.0
# 67                                      ELEVATORS_MEDI       0.0
# 68                                      ENTRANCES_MEDI       0.0
# 69                                      FLOORSMAX_MEDI       0.0
# 70                                      FLOORSMIN_MEDI       0.0
# 71                                       LANDAREA_MEDI       0.0
# 72                               LIVINGAPARTMENTS_MEDI       0.0
# 73                                     LIVINGAREA_MEDI       0.0
# 74                            NONLIVINGAPARTMENTS_MEDI       0.0
# 75                                  NONLIVINGAREA_MEDI       0.0
# 76                                      TOTALAREA_MODE       0.0
# 77                            OBS_30_CNT_SOCIAL_CIRCLE       0.0
# 78                            DEF_30_CNT_SOCIAL_CIRCLE       0.0
# 79                            OBS_60_CNT_SOCIAL_CIRCLE       0.0
# 80                            DEF_60_CNT_SOCIAL_CIRCLE       0.0
# 81                              DAYS_LAST_PHONE_CHANGE   -1770.0
# 82                                     FLAG_DOCUMENT_2         0
# 83                                     FLAG_DOCUMENT_3         0
# 84                                     FLAG_DOCUMENT_4         0
# 85                                     FLAG_DOCUMENT_5         0
# 86                                     FLAG_DOCUMENT_6         0
# 87                                     FLAG_DOCUMENT_7         0
# 88                                     FLAG_DOCUMENT_8         1
# 89                                     FLAG_DOCUMENT_9         0
# 90                                    FLAG_DOCUMENT_10         0
# 91                                    FLAG_DOCUMENT_11         0
# 92                                    FLAG_DOCUMENT_12         0
# 93                                    FLAG_DOCUMENT_13         0
# 94                                    FLAG_DOCUMENT_14         0
# 95                                    FLAG_DOCUMENT_15         0
# 96                                    FLAG_DOCUMENT_16         0
# 97                                    FLAG_DOCUMENT_17         0
# 98                                    FLAG_DOCUMENT_18         0
# 99                                    FLAG_DOCUMENT_19         0
# 100                                   FLAG_DOCUMENT_20         0
# 101                                   FLAG_DOCUMENT_21         0
# 102                         AMT_REQ_CREDIT_BUREAU_HOUR       0.0
# 103                          AMT_REQ_CREDIT_BUREAU_DAY       0.0
# 104                         AMT_REQ_CREDIT_BUREAU_WEEK       0.0
# 105                          AMT_REQ_CREDIT_BUREAU_MON       0.0
# 106                          AMT_REQ_CREDIT_BUREAU_QRT       0.0
# 107                         AMT_REQ_CREDIT_BUREAU_YEAR       0.0
# 108                                      CODE_GENDER_F     False
# 109                                      CODE_GENDER_M      True
# 110                           NAME_TYPE_SUITE_Children     False
# 111                             NAME_TYPE_SUITE_Family     False
# 112                    NAME_TYPE_SUITE_Group of people     False
# 113                            NAME_TYPE_SUITE_Other_A     False
# 114                            NAME_TYPE_SUITE_Other_B     False
# 115                    NAME_TYPE_SUITE_Spouse, partner     False
# 116                      NAME_TYPE_SUITE_Unaccompanied      True
# 117                       NAME_INCOME_TYPE_Businessman     False
# 118              NAME_INCOME_TYPE_Commercial associate     False
# 119                         NAME_INCOME_TYPE_Pensioner     False
# 120                     NAME_INCOME_TYPE_State servant     False
# 121                           NAME_INCOME_TYPE_Student     False
# 122                        NAME_INCOME_TYPE_Unemployed     False
# 123                           NAME_INCOME_TYPE_Working      True
# 124                NAME_EDUCATION_TYPE_Academic degree     False
# 125               NAME_EDUCATION_TYPE_Higher education      True
# 126              NAME_EDUCATION_TYPE_Incomplete higher     False
# 127                NAME_EDUCATION_TYPE_Lower secondary     False
# 128  NAME_EDUCATION_TYPE_Secondary / secondary special     False
# 129                  NAME_FAMILY_STATUS_Civil marriage     False
# 130                         NAME_FAMILY_STATUS_Married     False
# 131                       NAME_FAMILY_STATUS_Separated     False
# 132            NAME_FAMILY_STATUS_Single / not married      True
# 133                           NAME_FAMILY_STATUS_Widow     False
# 134                  NAME_HOUSING_TYPE_Co-op apartment     False
# 135                NAME_HOUSING_TYPE_House / apartment      True
# 136              NAME_HOUSING_TYPE_Municipal apartment     False
# 137                 NAME_HOUSING_TYPE_Office apartment     False
# 138                 NAME_HOUSING_TYPE_Rented apartment     False
# 139                     NAME_HOUSING_TYPE_With parents     False
# 140                        OCCUPATION_TYPE_Accountants     False
# 141                     OCCUPATION_TYPE_Cleaning staff     False
# 142                      OCCUPATION_TYPE_Cooking staff     False
# 143                         OCCUPATION_TYPE_Core staff     False
# 144                            OCCUPATION_TYPE_Drivers     False
# 145                           OCCUPATION_TYPE_HR staff     False
# 146              OCCUPATION_TYPE_High skill tech staff     False
# 147                           OCCUPATION_TYPE_IT staff     False
# 148                           OCCUPATION_TYPE_Laborers     False
# 149                 OCCUPATION_TYPE_Low-skill Laborers     False
# 150                           OCCUPATION_TYPE_Managers      True
# 151                     OCCUPATION_TYPE_Medicine staff     False
# 152              OCCUPATION_TYPE_Private service staff     False
# 153                      OCCUPATION_TYPE_Realty agents     False
# 154                        OCCUPATION_TYPE_Sales staff     False
# 155                        OCCUPATION_TYPE_Secretaries     False
# 156                     OCCUPATION_TYPE_Security staff     False
# 157               OCCUPATION_TYPE_Waiters/barmen staff     False
# 158                  WEEKDAY_APPR_PROCESS_START_FRIDAY     False
# 159                  WEEKDAY_APPR_PROCESS_START_MONDAY     False
# 160                WEEKDAY_APPR_PROCESS_START_SATURDAY     False
# 161                  WEEKDAY_APPR_PROCESS_START_SUNDAY     False
# 162                WEEKDAY_APPR_PROCESS_START_THURSDAY     False
# 163                 WEEKDAY_APPR_PROCESS_START_TUESDAY      True
# 164               WEEKDAY_APPR_PROCESS_START_WEDNESDAY     False
# 165                      ORGANIZATION_TYPE_Advertising     False
# 166                      ORGANIZATION_TYPE_Agriculture     False
# 167                             ORGANIZATION_TYPE_Bank     False
# 168           ORGANIZATION_TYPE_Business Entity Type 1     False
# 169           ORGANIZATION_TYPE_Business Entity Type 2     False
# 170           ORGANIZATION_TYPE_Business Entity Type 3     False
# 171                         ORGANIZATION_TYPE_Cleaning     False
# 172                     ORGANIZATION_TYPE_Construction     False
# 173                          ORGANIZATION_TYPE_Culture     False
# 174                      ORGANIZATION_TYPE_Electricity     False
# 175                        ORGANIZATION_TYPE_Emergency     False
# 176                       ORGANIZATION_TYPE_Government     False
# 177                            ORGANIZATION_TYPE_Hotel     False
# 178                          ORGANIZATION_TYPE_Housing     False
# 179                 ORGANIZATION_TYPE_Industry: type 1     False
# 180                ORGANIZATION_TYPE_Industry: type 10     False
# 181                ORGANIZATION_TYPE_Industry: type 11     False
# 182                ORGANIZATION_TYPE_Industry: type 12     False
# 183                ORGANIZATION_TYPE_Industry: type 13     False
# 184                 ORGANIZATION_TYPE_Industry: type 2     False
# 185                 ORGANIZATION_TYPE_Industry: type 3     False
# 186                 ORGANIZATION_TYPE_Industry: type 4     False
# 187                 ORGANIZATION_TYPE_Industry: type 5     False
# 188                 ORGANIZATION_TYPE_Industry: type 6     False
# 189                 ORGANIZATION_TYPE_Industry: type 7     False
# 190                 ORGANIZATION_TYPE_Industry: type 8     False
# 191                 ORGANIZATION_TYPE_Industry: type 9     False
# 192                        ORGANIZATION_TYPE_Insurance     False
# 193                     ORGANIZATION_TYPE_Kindergarten     False
# 194                   ORGANIZATION_TYPE_Legal Services     False
# 195                         ORGANIZATION_TYPE_Medicine      True
# 196                         ORGANIZATION_TYPE_Military     False
# 197                           ORGANIZATION_TYPE_Mobile     False
# 198                            ORGANIZATION_TYPE_Other     False
# 199                           ORGANIZATION_TYPE_Police     False
# 200                           ORGANIZATION_TYPE_Postal     False
# 201                          ORGANIZATION_TYPE_Realtor     False
# 202                         ORGANIZATION_TYPE_Religion     False
# 203                       ORGANIZATION_TYPE_Restaurant     False
# 204                           ORGANIZATION_TYPE_School     False
# 205                         ORGANIZATION_TYPE_Security     False
# 206              ORGANIZATION_TYPE_Security Ministries     False
# 207                    ORGANIZATION_TYPE_Self-employed     False
# 208                         ORGANIZATION_TYPE_Services     False
# 209                          ORGANIZATION_TYPE_Telecom     False
# 210                    ORGANIZATION_TYPE_Trade: type 1     False
# 211                    ORGANIZATION_TYPE_Trade: type 2     False
# 212                    ORGANIZATION_TYPE_Trade: type 3     False
# 213                    ORGANIZATION_TYPE_Trade: type 4     False
# 214                    ORGANIZATION_TYPE_Trade: type 5     False
# 215                    ORGANIZATION_TYPE_Trade: type 6     False
# 216                    ORGANIZATION_TYPE_Trade: type 7     False
# 217                ORGANIZATION_TYPE_Transport: type 1     False
# 218                ORGANIZATION_TYPE_Transport: type 2     False
# 219                ORGANIZATION_TYPE_Transport: type 3     False
# 220                ORGANIZATION_TYPE_Transport: type 4     False
# 221                       ORGANIZATION_TYPE_University     False
# 222                              ORGANIZATION_TYPE_XNA     False
# 223                   FONDKAPREMONT_MODE_not specified     False
# 224                FONDKAPREMONT_MODE_org spec account     False
# 225                FONDKAPREMONT_MODE_reg oper account     False
# 226           FONDKAPREMONT_MODE_reg oper spec account     False
# 227                      HOUSETYPE_MODE_block of flats     False
# 228                    HOUSETYPE_MODE_specific housing     False
# 229                      HOUSETYPE_MODE_terraced house     False
# 230                           WALLSMATERIAL_MODE_Block     False
# 231                           WALLSMATERIAL_MODE_Mixed     False
# 232                      WALLSMATERIAL_MODE_Monolithic     False
# 233                          WALLSMATERIAL_MODE_Others     False
# 234                           WALLSMATERIAL_MODE_Panel     False
# 235                    WALLSMATERIAL_MODE_Stone, brick     False
# 236                          WALLSMATERIAL_MODE_Wooden     False
# 237                             EMERGENCYSTATE_MODE_No     False
# 238                            EMERGENCYSTATE_MODE_Yes     False
# 239                                             TARGET         0
# 240                                 DAYS_EMPLOYED_ANOM     False
